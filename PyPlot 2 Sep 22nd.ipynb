# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns
from scipy.stats import norm
from sklearn.preprocessing import StandardScaler
from scipy import stats
# %matplotlib inline

# %% [markdown]
# # 주택 가격 예측데이터 분석
# - 상관관계
# - 결측치 처리
# - 이상치 처리
# - 로그 반환

# %%
df_train = pd.read_csv('./data/train.csv')

# %%
df_train.T
# Out:
#                   0        1        2        3        4        5        6     \
# Id                   1        2        3        4        5        6        7
# MSSubClass          60       20       60       70       60       50       20
# MSZoning            RL       RL       RL       RL       RL       RL       RL
# LotFrontage         65       80       68       60       84       85       75
# LotArea           8450     9600    11250     9550    14260    14115    10084
# Street            Pave     Pave     Pave     Pave     Pave     Pave     Pave
# Alley              NaN      NaN      NaN      NaN      NaN      NaN      NaN
# LotShape           Reg      Reg      IR1      IR1      IR1      IR1      Reg
# LandContour        Lvl      Lvl      Lvl      Lvl      Lvl      Lvl      Lvl
# Utilities       AllPub   AllPub   AllPub   AllPub   AllPub   AllPub   AllPub
# LotConfig       Inside      FR2   Inside   Corner      FR2   Inside   Inside
# ...

# %%
df_train.shape
# Out:
# (1460, 81)

# %%
df_train.columns
# Out:
# Index(['Id', 'MSSubClass', 'MSZoning', 'LotFrontage', 'LotArea', 'Street',
#        'Alley', 'LotShape', 'LandContour', 'Utilities', 'LotConfig',
#        'LandSlope', 'Neighborhood', 'Condition1', 'Condition2', 'BldgType',
#        'HouseStyle', 'OverallQual', 'OverallCond', 'YearBuilt', 'YearRemodAdd',
#        'RoofStyle', 'RoofMatl', 'Exterior1st', 'Exterior2nd', 'MasVnrType',
#        'MasVnrArea', 'ExterQual', 'ExterCond', 'Foundation', 'BsmtQual',
#        'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinSF1',
#        'BsmtFinType2', 'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF', 'Heating',
#        'HeatingQC', 'CentralAir', 'Electrical', '1stFlrSF', '2ndFlrSF',
#        'LowQualFinSF', 'GrLivArea', 'BsmtFullBath', 'BsmtHalfBath', 'FullBath',
#        'HalfBath', 'BedroomAbvGr', 'KitchenAbvGr', 'KitchenQual',
#        'TotRmsAbvGrd', 'Functional', 'Fireplaces', 'FireplaceQu', 'GarageType',
#        'GarageYrBlt', 'GarageFinish', 'GarageCars', 'GarageArea', 'GarageQual',
# ...

# %% [markdown]
# ## the most important features (known as)
# - OverallQual
# - YearBuilt
# - GarageCars
# - GarageArea
# - TotalBsmtSF
# - GrLivArea

# %%
corrmat = df_train.corr()
f, ax = plt.subplots(figsize=(12,9))
sns.heatmap(corrmat, vmax=0.8, square=True)

# %%
corrmat.sort_values('SalePrice', ascending=False).T.tail()
# Out:
#            SalePrice  OverallQual  GrLivArea  GarageCars  GarageArea  \
# PoolArea    0.092404     0.065166   0.170205    0.020934    0.061047
# MiscVal    -0.021190    -0.031406  -0.002416   -0.043080   -0.027400
# MoSold      0.046432     0.070815   0.050240    0.040522    0.027974
# YrSold     -0.028923    -0.027347  -0.036526   -0.039117   -0.027378
# SalePrice   1.000000     0.790982   0.708624    0.640409    0.623431
#
#            TotalBsmtSF  1stFlrSF  FullBath  TotRmsAbvGrd  YearBuilt  ...  \
# PoolArea      0.126053  0.131525  0.049604      0.083757   0.004950  ...
# MiscVal      -0.018479 -0.021096 -0.014290      0.024763  -0.034383  ...
# MoSold        0.013196  0.031372  0.055872      0.036907   0.012398  ...
# YrSold       -0.014969 -0.013604 -0.019669     -0.034516  -0.013618  ...
# SalePrice     0.613581  0.605852  0.560664      0.533723   0.522897  ...
#
#            BsmtFinSF2  BsmtHalfBath   MiscVal        Id  LowQualFinSF  \
# ...

# %%
df_train.shape
# Out:
# (1460, 81)

# %%
df_train['SalePrice'].describe()
# Out:
# count      1460.000000
# mean     180921.195890
# std       79442.502883
# min       34900.000000
# 25%      129975.000000
# 50%      163000.000000
# 75%      214000.000000
# max      755000.000000
# Name: SalePrice, dtype: float64

# %%
sns.distplot(df_train['SalePrice'])   # distribution (density)

# %%
# skewness(왜도) and kurtosis(첨도)
df_train['SalePrice'].skew()
# Out:
# 1.8828757597682129

# %%
df_train['SalePrice'].kurt()
# Out:
# 6.536281860064529

# %%
# exercise for skewness and kurtosis
sample_df = pd.DataFrame(10*np.random.randn(10000, 1))
sample_df.head()
# Out:
#            0
# 0   5.914767
# 1 -16.117315
# 2  -3.940836
# 3  -3.922563
# 4 -18.742940

# %%
print(sample_df.skew(), '\n', sample_df.kurt())
# Out:
# 0    0.02728
# dtype: float64
#  0    0.000724
# dtype: float64

# %%
sns.distplot(sample_df)

# %%
# 산포도 (scatter plot) for 변수들의 관계 파악
var = 'GrLivArea'
data = pd.concat([df_train['SalePrice'], df_train[var]], axis=1)
data
# Out:
#       SalePrice  GrLivArea
# 0        208500       1710
# 1        181500       1262
# 2        223500       1786
# 3        140000       1717
# 4        250000       2198
# 5        143000       1362
# 6        307000       1694
# 7        200000       2090
# 8        129900       1774
# 9        118000       1077
# 10       129500       1040
# 11       345000       2324
# 12       144000        912
# 13       279500       1494
# 14       157000       1253
# 15       132000        854
# 16       149000       1004
# 17        90000       1296
# 18       159000       1114
# 19       139000       1339
# 20       325300       2376
# 21       139400       1108
# 22       230000       1795
# 23       129900       1060
# 24       154000       1060
# 25       256300       1600
# 26       134800        900
# 27       306000       1704
# 28       207500       1600
# 29        68500        520
# ...         ...        ...
# 1430     192140       1838
# 1431     143750        958
# ...

# %%
data.plot.scatter(x=var, y='SalePrice', xlim=(0,4600), ylim=(0,800000))

# %%
var = 'OverallQual'
data = pd.concat([df_train['SalePrice'], df_train[var]], axis=1)
data.plot.scatter(x=var, y='SalePrice', ylim=(0,800000))

# %%
var = 'TotalBsmtSF'
data = pd.concat([df_train['SalePrice'], df_train[var]], axis=1)
data.plot.scatter(x=var, y='SalePrice')

# %%
# catagorical feature 들과의 관계
df_train['OverallQual'].unique()
# Out:
# array([ 7,  6,  8,  5,  9,  4, 10,  3,  1,  2])

# %%
plt.subplots(figsize=(8,6))
fig = sns.boxplot(x=var, y='SalePrice', data=data)
fig.axis(ymin=0, ymax=800000)
# Out:
# (-0.5, 720.5, 0, 800000)

# %%
df_train['OverallQual'].value_counts()
# Out:
# 5     397
# 6     374
# 7     319
# 8     168
# 4     116
# 9      43
# 3      20
# 10     18
# 2       3
# 1       2
# Name: OverallQual, dtype: int64

# %%
df_train['GarageCars'].unique()
# Out:
# array([2, 3, 1, 0, 4])

# %%
df_train['GarageCars'].value_counts()
# Out:
# 2    824
# 1    369
# 3    181
# 0     81
# 4      5
# Name: GarageCars, dtype: int64

# %%
var = 'GarageCars'
data = pd.concat([df_train['SalePrice'], df_train[var]], axis=1)
data.plot.scatter(x=var, y='SalePrice')

# %%
var = 'YearBuilt'
data = pd.concat([df_train['SalePrice'], df_train[var]], axis=1)
data.plot.scatter(x=var, y='SalePrice')

plt.subplots(figsize=(8,6))
fig = sns.boxplot(x=var, y='SalePrice', data=data)
fig.axis(ymin=0, ymax=800000)
# Out:
# (-0.5, 111.5, 0, 800000)

# %%
corrmat = df_train.corr()
corrmat
# Out:
#                      Id  MSSubClass  LotFrontage   LotArea  OverallQual  \
# Id             1.000000    0.011156    -0.010601 -0.033226    -0.028365
# MSSubClass     0.011156    1.000000    -0.386347 -0.139781     0.032628
# LotFrontage   -0.010601   -0.386347     1.000000  0.426095     0.251646
# LotArea       -0.033226   -0.139781     0.426095  1.000000     0.105806
# OverallQual   -0.028365    0.032628     0.251646  0.105806     1.000000
# OverallCond    0.012609   -0.059316    -0.059213 -0.005636    -0.091932
# YearBuilt     -0.012713    0.027850     0.123349  0.014228     0.572323
# YearRemodAdd  -0.021998    0.040581     0.088866  0.013788     0.550684
# MasVnrArea    -0.050298    0.022936     0.193458  0.104160     0.411876
# BsmtFinSF1    -0.005024   -0.069836     0.233633  0.214103     0.239666
# BsmtFinSF2    -0.005968   -0.065649     0.049900  0.111170    -0.059119
# BsmtUnfSF     -0.007940   -0.140759     0.132644 -0.002618     0.308159
# ...

# %%
k = 5
cols = corrmat.nlargest(6, 'SalePrice')
cols['SalePrice']

cols = cols.index
cols
# Out:
# Index(['SalePrice', 'OverallQual', 'GrLivArea', 'GarageCars', 'GarageArea',
#        'TotalBsmtSF'],
#       dtype='object')

# %%
df_train[cols].T
# Out:
#                0       1       2       3       4       5       6       7     \
# SalePrice    208500  181500  223500  140000  250000  143000  307000  200000
# OverallQual       7       6       7       7       8       5       8       7
# GrLivArea      1710    1262    1786    1717    2198    1362    1694    2090
# GarageCars        2       2       2       3       3       2       2       2
# GarageArea      548     460     608     642     836     480     636     484
# TotalBsmtSF     856    1262     920     756    1145     796    1686    1107
#
#                8       9     ...    1450    1451    1452   1453    1454  \
# SalePrice    129900  118000  ...  136000  287090  145000  84500  185000
# OverallQual       7       5  ...       5       8       5      5       7
# GrLivArea      1774    1077  ...    1792    1578    1072   1140    1221
# GarageCars        2       1  ...       0       3       2      0       2
# GarageArea      468     205  ...       0     840     525      0     400
# ...

# %%
cm = np.corrcoef(df_train[cols].values.T)
cm
# Out:
# array([[1.        , 0.7909816 , 0.70862448, 0.6404092 , 0.62343144,
#         0.61358055],
#        [0.7909816 , 1.        , 0.59300743, 0.60067072, 0.56202176,
#         0.5378085 ],
#        [0.70862448, 0.59300743, 1.        , 0.46724742, 0.46899748,
#         0.4548682 ],
#        [0.6404092 , 0.60067072, 0.46724742, 1.        , 0.88247541,
#         0.43458483],
#        [0.62343144, 0.56202176, 0.46899748, 0.88247541, 1.        ,
#         0.48666546],
#        [0.61358055, 0.5378085 , 0.4548682 , 0.43458483, 0.48666546,
#         1.        ]])

# %%
cols = ['SalePrice', 'OverallQual', 'GrLivArea', 'GarageCars', 'TotalBsmtSF', 'FullBath', 'YearBuilt']
sns.pairplot(df_train[cols], size=2)
plt.show()
# Out:
# /Users/Dodanto/anaconda3/lib/python3.7/site-packages/seaborn/axisgrid.py:2065: UserWarning: The `size` parameter has been renamed to `height`; pleaes update your code.
#   warnings.warn(msg, UserWarning)

# %% [markdown]
# ### 결측치 처리

# %%
# exercise
array = np.array([[1, np.nan, 3],
                [4, 5, np.nan]])
array
# Out:
# array([[ 1., nan,  3.],
#        [ 4.,  5., nan]])

# %%
pd.isna(array)
# Out:
# array([[False,  True, False],
#        [False, False,  True]])

# %%
pd.isna(array[0])
# Out:
# array([False,  True, False])

# %%
df = pd.DataFrame([['ant','bee','cat'],
                  ['dog', None, 'fly']], columns=['A','B','C'])
df
# Out:
#      A     B    C
# 0  ant   bee  cat
# 1  dog  None  fly

# %%
df['A']
# Out:
# 0    ant
# 1    dog
# Name: A, dtype: object

# %%
df.A
# Out:
# 0    ant
# 1    dog
# Name: A, dtype: object

# %%
pd.isna(df)
# Out:
#        A      B      C
# 0  False  False  False
# 1  False   True  False

# %%
# Back to the original problem
df_train.describe()
# Out:
#                 Id   MSSubClass  LotFrontage        LotArea  OverallQual  \
# count  1460.000000  1460.000000  1201.000000    1460.000000  1460.000000
# mean    730.500000    56.897260    70.049958   10516.828082     6.099315
# std     421.610009    42.300571    24.284752    9981.264932     1.382997
# min       1.000000    20.000000    21.000000    1300.000000     1.000000
# 25%     365.750000    20.000000    59.000000    7553.500000     5.000000
# 50%     730.500000    50.000000    69.000000    9478.500000     6.000000
# 75%    1095.250000    70.000000    80.000000   11601.500000     7.000000
# max    1460.000000   190.000000   313.000000  215245.000000    10.000000
#
#        OverallCond    YearBuilt  YearRemodAdd   MasVnrArea   BsmtFinSF1  ...  \
# count  1460.000000  1460.000000   1460.000000  1452.000000  1460.000000  ...
# mean      5.575342  1971.267808   1984.865753   103.685262   443.639726  ...
# std       1.112799    30.202904     20.645407   181.066207   456.098091  ...
# ...

# %%
df_train.isna().head(10)
# Out:
#       Id  MSSubClass  MSZoning  LotFrontage  LotArea  Street  Alley  LotShape  \
# 0  False       False     False        False    False   False   True     False
# 1  False       False     False        False    False   False   True     False
# 2  False       False     False        False    False   False   True     False
# 3  False       False     False        False    False   False   True     False
# 4  False       False     False        False    False   False   True     False
# 5  False       False     False        False    False   False   True     False
# 6  False       False     False        False    False   False   True     False
# 7  False       False     False         True    False   False   True     False
# 8  False       False     False        False    False   False   True     False
# 9  False       False     False        False    False   False   True     False
#
#    LandContour  Utilities  ...  PoolArea  PoolQC  Fence  MiscFeature  MiscVal  \
# ...

# %%
df_train.isna().sum()
# Out:
# Id                  0
# MSSubClass          0
# MSZoning            0
# LotFrontage       259
# LotArea             0
# Street              0
# Alley            1369
# LotShape            0
# LandContour         0
# Utilities           0
# LotConfig           0
# LandSlope           0
# Neighborhood        0
# Condition1          0
# Condition2          0
# BldgType            0
# HouseStyle          0
# OverallQual         0
# OverallCond         0
# YearBuilt           0
# YearRemodAdd        0
# RoofStyle           0
# RoofMatl            0
# Exterior1st         0
# Exterior2nd         0
# MasVnrType          8
# MasVnrArea          8
# ExterQual           0
# ExterCond           0
# Foundation          0
#                  ...
# BedroomAbvGr        0
# KitchenAbvGr        0
# KitchenQual         0
# TotRmsAbvGrd        0
# Functional          0
# Fireplaces          0
# FireplaceQu       690
# GarageType         81
# GarageYrBlt        81
# GarageFinish       81
# ...

# %%
df_train.count()   # non-NA cells 개수
# Out:
# Id               1460
# MSSubClass       1460
# MSZoning         1460
# LotFrontage      1201
# LotArea          1460
# Street           1460
# Alley              91
# LotShape         1460
# LandContour      1460
# Utilities        1460
# LotConfig        1460
# LandSlope        1460
# Neighborhood     1460
# Condition1       1460
# Condition2       1460
# BldgType         1460
# HouseStyle       1460
# OverallQual      1460
# OverallCond      1460
# YearBuilt        1460
# YearRemodAdd     1460
# RoofStyle        1460
# RoofMatl         1460
# Exterior1st      1460
# Exterior2nd      1460
# MasVnrType       1452
# MasVnrArea       1452
# ExterQual        1460
# ExterCond        1460
# Foundation       1460
#                  ...
# BedroomAbvGr     1460
# KitchenAbvGr     1460
# KitchenQual      1460
# TotRmsAbvGrd     1460
# Functional       1460
# Fireplaces       1460
# FireplaceQu       770
# GarageType       1379
# GarageYrBlt      1379
# GarageFinish     1379
# ...

# %%
total = df_train.isnull().sum().sort_values(ascending=False)
total.head(5)
# Out:
# PoolQC         1453
# MiscFeature    1406
# Alley          1369
# Fence          1179
# FireplaceQu     690
# dtype: int64

# %%
percent = (df_train.isna().sum()/df_train.shape[0]).sort_values(ascending=False)
percent.head(10)
# Out:
# PoolQC          0.995205
# MiscFeature     0.963014
# Alley           0.937671
# Fence           0.807534
# FireplaceQu     0.472603
# LotFrontage     0.177397
# GarageCond      0.055479
# GarageType      0.055479
# GarageYrBlt     0.055479
# GarageFinish    0.055479
# dtype: float64

# %%
missing_data = pd.concat([total, percent], axis=1, keys=['total','percent'])
missing_data
# Out:
#                total   percent
# PoolQC          1453  0.995205
# MiscFeature     1406  0.963014
# Alley           1369  0.937671
# Fence           1179  0.807534
# FireplaceQu      690  0.472603
# LotFrontage      259  0.177397
# GarageCond        81  0.055479
# GarageType        81  0.055479
# GarageYrBlt       81  0.055479
# GarageFinish      81  0.055479
# GarageQual        81  0.055479
# BsmtExposure      38  0.026027
# BsmtFinType2      38  0.026027
# BsmtFinType1      37  0.025342
# BsmtCond          37  0.025342
# BsmtQual          37  0.025342
# MasVnrArea         8  0.005479
# MasVnrType         8  0.005479
# Electrical         1  0.000685
# Utilities          0  0.000000
# YearRemodAdd       0  0.000000
# MSSubClass         0  0.000000
# Foundation         0  0.000000
# ExterCond          0  0.000000
# ExterQual          0  0.000000
# Exterior2nd        0  0.000000
# Exterior1st        0  0.000000
# RoofMatl           0  0.000000
# RoofStyle          0  0.000000
# ...

# %%
missing_data[missing_data['total'] > 1].index
# Out:
# Index(['PoolQC', 'MiscFeature', 'Alley', 'Fence', 'FireplaceQu', 'LotFrontage',
#        'GarageCond', 'GarageType', 'GarageYrBlt', 'GarageFinish', 'GarageQual',
#        'BsmtExposure', 'BsmtFinType2', 'BsmtFinType1', 'BsmtCond', 'BsmtQual',
#        'MasVnrArea', 'MasVnrType'],
#       dtype='object')

# %%
# missing rate가 50%이상인 것은 drop
# Electrical은 entry 삭제
df_train = pd.read_csv('./data/train.csv')
df_train2 = df_train.drop(missing_data[missing_data['total'] > 1].index, axis=1)
df_train2.head()
# Out:
#    Id  MSSubClass MSZoning  LotArea Street LotShape LandContour Utilities  \
# 0   1          60       RL     8450   Pave      Reg         Lvl    AllPub
# 1   2          20       RL     9600   Pave      Reg         Lvl    AllPub
# 2   3          60       RL    11250   Pave      IR1         Lvl    AllPub
# 3   4          70       RL     9550   Pave      IR1         Lvl    AllPub
# 4   5          60       RL    14260   Pave      IR1         Lvl    AllPub
#
#   LotConfig LandSlope  ... EnclosedPorch 3SsnPorch ScreenPorch PoolArea  \
# 0    Inside       Gtl  ...             0         0           0        0
# 1       FR2       Gtl  ...             0         0           0        0
# 2    Inside       Gtl  ...             0         0           0        0
# 3    Corner       Gtl  ...           272         0           0        0
# 4       FR2       Gtl  ...             0         0           0        0
#
#   MiscVal  MoSold  YrSold  SaleType  SaleCondition SalePrice
# ...

# %%
df_train2.shape
# Out:
# (1460, 63)

# %%
df_train3 = df_train2.drop(df_train2.loc[df_train2['Electrical'].isna()].index)
df_train3.isnull().sum().max()
# Out:
# 0

# %%
df_train3.shape
# Out:
# (1459, 63)

# %%
### Outlier (특이값, 이상치 처리)
sc = StandardScaler()
saleprice_scaled = sc.fit_transform(np.array(df_train3['SalePrice']).reshape(-1, 1))
saleprice_scaled
# Out:
# /Users/Dodanto/anaconda3/lib/python3.7/site-packages/sklearn/utils/validation.py:595: DataConversionWarning: Data with input dtype int64 was converted to float64 by StandardScaler.
#   warnings.warn(msg, DataConversionWarning)
# /Users/Dodanto/anaconda3/lib/python3.7/site-packages/sklearn/utils/validation.py:595: DataConversionWarning: Data with input dtype int64 was converted to float64 by StandardScaler.
#   warnings.warn(msg, DataConversionWarning)
# array([[ 0.34704187],
#        [ 0.0071701 ],
#        [ 0.53585953],
#        ...,
#        [ 1.07713679],
#        [-0.48847623],
#        [-0.42081658]])

# %%
saleprice_scaled[:,0]
# Out:
# array([ 0.34704187,  0.0071701 ,  0.53585953, ...,  1.07713679,
#        -0.48847623, -0.42081658])

# %%
low_range = saleprice_scaled[saleprice_scaled[:,0].argsort()][:10]
high_range = saleprice_scaled[saleprice_scaled[:,0].argsort()][-10:]

# %%
plt.plot(df_train3['SalePrice'])

# %%
plt.plot(saleprice_scaled)

# %%
# bivariate 분석
var = 'GrLivArea'
data = pd.concat([df_train3['SalePrice'], df_train[var]], axis=1)
data.plot.scatter(x=var, y='SalePrice')

# %%
df_train3.sort_values(by='GrLivArea', ascending=False)[:2]
# Out:
#         Id  MSSubClass MSZoning  LotArea Street LotShape LandContour  \
# 1298  1299          60       RL    63887   Pave      IR3         Bnk
# 523    524          60       RL    40094   Pave      IR1         Bnk
#
#      Utilities LotConfig LandSlope  ... EnclosedPorch 3SsnPorch ScreenPorch  \
# 1298    AllPub    Corner       Gtl  ...             0         0           0
# 523     AllPub    Inside       Gtl  ...             0         0           0
#
#      PoolArea MiscVal  MoSold  YrSold  SaleType  SaleCondition SalePrice
# 1298      480       0       1    2008       New        Partial    160000
# 523         0       0      10    2007       New        Partial    184750
#
# [2 rows x 63 columns]

# %%
df_train3 = df_train3.drop(df_train3[df_train3['Id']==1299].index)
df_train3 = df_train3.drop(df_train3[df_train3['Id']==524].index)
df_train3.sort_values(by='GrLivArea', ascending=False)[:2]
# Out:
#         Id  MSSubClass MSZoning  LotArea Street LotShape LandContour  \
# 1182  1183          60       RL    15623   Pave      IR1         Lvl
# 691    692          60       RL    21535   Pave      IR1         Lvl
#
#      Utilities LotConfig LandSlope  ... EnclosedPorch 3SsnPorch ScreenPorch  \
# 1182    AllPub    Corner       Gtl  ...             0         0           0
# 691     AllPub    Corner       Gtl  ...             0         0           0
#
#      PoolArea MiscVal  MoSold  YrSold  SaleType  SaleCondition SalePrice
# 1182      555       0       7    2007        WD        Abnorml    745000
# 691         0       0       1    2007        WD         Normal    755000
#
# [2 rows x 63 columns]

# %%
df_train3[df_train3['Id']==1183]
# Out:
#         Id  MSSubClass MSZoning  LotArea Street LotShape LandContour  \
# 1182  1183          60       RL    15623   Pave      IR1         Lvl
#
#      Utilities LotConfig LandSlope  ... EnclosedPorch 3SsnPorch ScreenPorch  \
# 1182    AllPub    Corner       Gtl  ...             0         0           0
#
#      PoolArea MiscVal  MoSold  YrSold  SaleType  SaleCondition SalePrice
# 1182      555       0       7    2007        WD        Abnorml    745000
#
# [1 rows x 63 columns]

# %%
# Using Scaled Variables

grlivare_scaled = sc.fit_transform(np.array(df_train3['GrLivArea']).reshape(-1, 1))
grlivare_scaled
# Out:
# /Users/Dodanto/anaconda3/lib/python3.7/site-packages/sklearn/utils/validation.py:595: DataConversionWarning: Data with input dtype int64 was converted to float64 by StandardScaler.
#   warnings.warn(msg, DataConversionWarning)
# /Users/Dodanto/anaconda3/lib/python3.7/site-packages/sklearn/utils/validation.py:595: DataConversionWarning: Data with input dtype int64 was converted to float64 by StandardScaler.
#   warnings.warn(msg, DataConversionWarning)
# array([[ 0.3927277 ],
#        [-0.48938895],
#        [ 0.54237249],
#        ...,
#        [ 1.63320425],
#        [-0.85168686],
#        [-0.50120301]])

# %%
saleprice_scaled = sc.fit_transform(np.log(np.array(df_train3['SalePrice']).reshape(-1, 1)))
data = pd.DataFrame([saleprice_scaled[:,0], grlivare_scaled[:,0]]).T
data.columns = ['saleprice_scaled','grlivarea_scaled']
data.head()
# Out:
#    saleprice_scaled  grlivarea_scaled
# 0          0.559620          0.392728
# 1          0.212665         -0.489389
# 2          0.733425          0.542372
# 3         -0.436830          0.406511
# 4          1.013748          1.353605

# %%
data.plot.scatter(x='grlivarea_scaled', y='saleprice_scaled')

# %%
# exercise argsort

x = np.array([1,4,2,8,3])
np.sort(x)
np.argsort(x)   # 정렬된 요소의 인덱스를 보고싶을 때
# Out:
# array([0, 2, 4, 1, 3])
